# %%
import pandas as pd

df = pd.read_csv('landmarksData.csv')

# print(df.to_string())

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df
# Out:
#       THUMB_CMC_X  THUMB_CMC_Y  THUMB_CMC_Z  THUMB_MCP_X  THUMB_MCP_Y  \
# 0        0.822913     0.811217    -0.030279     0.769882     0.810273
# 1        0.796208     0.785647    -0.027506     0.743264     0.785662
# 2        0.788705     0.776697    -0.026980     0.736030     0.780502
# 3        0.790119     0.777986    -0.027492     0.736656     0.780400
# 4        0.796043     0.779467    -0.026090     0.743369     0.781562
# ...           ...          ...          ...          ...          ...
# 5496     0.260664     0.811222    -0.026568     0.240920     0.758979
# 5497     0.263584     0.808559    -0.026927     0.243488     0.755336
# 5498     0.269461     0.809046    -0.026965     0.249336     0.755363
# 5499     0.269065     0.820973    -0.025977     0.251147     0.766603
# 5500     0.226780     0.861520    -0.029988     0.210698     0.803030
#
#       THUMB_MCP_Z  THUMB_IP_X  THUMB_IP_Y  THUMB_IP_Z  THUMB_TIP_X  ...  \
# 0       -0.046193    0.723707    0.805570   -0.059408     0.686629  ...
# 1       -0.042377    0.696398    0.783449   -0.055750     0.659238  ...
# 2       -0.041957    0.688400    0.778305   -0.055501     0.652042  ...
# 3       -0.043466    0.689220    0.778362   -0.058055     0.651937  ...
# 4       -0.041681    0.696130    0.779632   -0.056151     0.659827  ...
# ...           ...         ...         ...         ...          ...  ...
# 5496    -0.028271    0.203404    0.735841   -0.027329     0.172173  ...
# 5497    -0.028273    0.205505    0.733298   -0.026750     0.174160  ...
# 5498    -0.028016    0.211571    0.733401   -0.026295     0.179941  ...
# 5499    -0.030492    0.211980    0.742309   -0.033006     0.179677  ...
# 5500    -0.030010    0.174299    0.782218   -0.027446     0.144423  ...
#
#       PINKY_PIP_X  PINKY_PIP_Y  PINKY_PIP_Z  PINKY_DIP_X  PINKY_DIP_Y  \
# 0        0.825230     1.027323    -0.042133     0.818573     1.055026
# 1        0.804704     1.013823    -0.049552     0.800856     1.046382
# 2        0.801652     1.007462    -0.051735     0.798213     1.041260
# 3        0.805184     1.009477    -0.054457     0.800232     1.041650
# 4        0.815881     1.010954    -0.055435     0.811484     1.046293
# ...           ...          ...          ...          ...          ...
# 5496     0.175680     0.764442    -0.011767     0.184664     0.784651
# 5497     0.179314     0.762118    -0.011789     0.189291     0.781433
# 5498     0.184632     0.762782    -0.013189     0.195506     0.781406
# 5499     0.184120     0.771893    -0.023345     0.195952     0.791832
# 5500     0.147141     0.818135    -0.014641     0.153977     0.845216
#
#       PINKY_DIP_Z  PINKY_TIP_X  PINKY_TIP_Y  PINKY_TIP_Z  CLASS
# 0       -0.046362     0.810923     1.079428    -0.048673      0
# 1       -0.056060     0.796632     1.076262    -0.060052      0
# 2       -0.058541     0.793435     1.073090    -0.063101      0
# 3       -0.060612     0.793955     1.071162    -0.064699      0
# 4       -0.063023     0.805646     1.078444    -0.068271      0
# ...           ...          ...          ...          ...    ...
# 5496    -0.019742     0.196799     0.799457    -0.019574      3
# 5497    -0.019686     0.201728     0.795527    -0.019454      3
# 5498    -0.021070     0.208102     0.795988    -0.021101      3
# 5499    -0.028024     0.208396     0.806216    -0.024714      3
# 5500    -0.025555     0.166225     0.861732    -0.025998      3
#
# [5501 rows x 61 columns]

# %%
# Function that Convert Dataframe to Bunch
from sklearn.utils import Bunch
def dataframe_to_bunch(df, name):
    data = df.drop(name, axis=1)
    target = df[name]
    # Height = list(df.Height)
    # Weight = list(shirt.Weight)
    # target_names = list(shirt.Class)
    return Bunch(data=data, target=target)
name ="CLASS"
bunch = dataframe_to_bunch(df, name)

# %%
bunch.data
# Out:
#       THUMB_CMC_X  THUMB_CMC_Y  THUMB_CMC_Z  THUMB_MCP_X  THUMB_MCP_Y  \
# 0        0.822913     0.811217    -0.030279     0.769882     0.810273
# 1        0.796208     0.785647    -0.027506     0.743264     0.785662
# 2        0.788705     0.776697    -0.026980     0.736030     0.780502
# 3        0.790119     0.777986    -0.027492     0.736656     0.780400
# 4        0.796043     0.779467    -0.026090     0.743369     0.781562
# ...           ...          ...          ...          ...          ...
# 5496     0.260664     0.811222    -0.026568     0.240920     0.758979
# 5497     0.263584     0.808559    -0.026927     0.243488     0.755336
# 5498     0.269461     0.809046    -0.026965     0.249336     0.755363
# 5499     0.269065     0.820973    -0.025977     0.251147     0.766603
# 5500     0.226780     0.861520    -0.029988     0.210698     0.803030
#
#       THUMB_MCP_Z  THUMB_IP_X  THUMB_IP_Y  THUMB_IP_Z  THUMB_TIP_X  ...  \
# 0       -0.046193    0.723707    0.805570   -0.059408     0.686629  ...
# 1       -0.042377    0.696398    0.783449   -0.055750     0.659238  ...
# 2       -0.041957    0.688400    0.778305   -0.055501     0.652042  ...
# 3       -0.043466    0.689220    0.778362   -0.058055     0.651937  ...
# 4       -0.041681    0.696130    0.779632   -0.056151     0.659827  ...
# ...           ...         ...         ...         ...          ...  ...
# 5496    -0.028271    0.203404    0.735841   -0.027329     0.172173  ...
# 5497    -0.028273    0.205505    0.733298   -0.026750     0.174160  ...
# 5498    -0.028016    0.211571    0.733401   -0.026295     0.179941  ...
# 5499    -0.030492    0.211980    0.742309   -0.033006     0.179677  ...
# 5500    -0.030010    0.174299    0.782218   -0.027446     0.144423  ...
#
#       PINKY_MCP_Z  PINKY_PIP_X  PINKY_PIP_Y  PINKY_PIP_Z  PINKY_DIP_X  \
# 0       -0.030241     0.825230     1.027323    -0.042133     0.818573
# 1       -0.036056     0.804704     1.013823    -0.049552     0.800856
# 2       -0.038206     0.801652     1.007462    -0.051735     0.798213
# 3       -0.040409     0.805184     1.009477    -0.054457     0.800232
# 4       -0.041111     0.815881     1.010954    -0.055435     0.811484
# ...           ...          ...          ...          ...          ...
# 5496     0.011071     0.175680     0.764442    -0.011767     0.184664
# 5497     0.010828     0.179314     0.762118    -0.011789     0.189291
# 5498     0.009101     0.184632     0.762782    -0.013189     0.195506
# 5499     0.000387     0.184120     0.771893    -0.023345     0.195952
# 5500     0.014342     0.147141     0.818135    -0.014641     0.153977
#
#       PINKY_DIP_Y  PINKY_DIP_Z  PINKY_TIP_X  PINKY_TIP_Y  PINKY_TIP_Z
# 0        1.055026    -0.046362     0.810923     1.079428    -0.048673
# 1        1.046382    -0.056060     0.796632     1.076262    -0.060052
# 2        1.041260    -0.058541     0.793435     1.073090    -0.063101
# 3        1.041650    -0.060612     0.793955     1.071162    -0.064699
# 4        1.046293    -0.063023     0.805646     1.078444    -0.068271
# ...           ...          ...          ...          ...          ...
# 5496     0.784651    -0.019742     0.196799     0.799457    -0.019574
# 5497     0.781433    -0.019686     0.201728     0.795527    -0.019454
# 5498     0.781406    -0.021070     0.208102     0.795988    -0.021101
# 5499     0.791832    -0.028024     0.208396     0.806216    -0.024714
# 5500     0.845216    -0.025555     0.166225     0.861732    -0.025998
#
# [5501 rows x 60 columns]

# %%
x = df.iloc[:,0:60]
x.head()
# print(type(x))
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(X,y_new, train_size= 0.8)
# print(X_test.shape)
# print(X_train.shape)
# Out:
#    THUMB_CMC_X  THUMB_CMC_Y  THUMB_CMC_Z  THUMB_MCP_X  THUMB_MCP_Y  \
# 0     0.822913     0.811217    -0.030279     0.769882     0.810273
# 1     0.796208     0.785647    -0.027506     0.743264     0.785662
# 2     0.788705     0.776697    -0.026980     0.736030     0.780502
# 3     0.790119     0.777986    -0.027492     0.736656     0.780400
# 4     0.796043     0.779467    -0.026090     0.743369     0.781562
#
#    THUMB_MCP_Z  THUMB_IP_X  THUMB_IP_Y  THUMB_IP_Z  THUMB_TIP_X  ...  \
# 0    -0.046193    0.723707    0.805570   -0.059408     0.686629  ...
# 1    -0.042377    0.696398    0.783449   -0.055750     0.659238  ...
# 2    -0.041957    0.688400    0.778305   -0.055501     0.652042  ...
# 3    -0.043466    0.689220    0.778362   -0.058055     0.651937  ...
# 4    -0.041681    0.696130    0.779632   -0.056151     0.659827  ...
#
#    PINKY_MCP_Z  PINKY_PIP_X  PINKY_PIP_Y  PINKY_PIP_Z  PINKY_DIP_X  \
# 0    -0.030241     0.825230     1.027323    -0.042133     0.818573
# 1    -0.036056     0.804704     1.013823    -0.049552     0.800856
# 2    -0.038206     0.801652     1.007462    -0.051735     0.798213
# 3    -0.040409     0.805184     1.009477    -0.054457     0.800232
# 4    -0.041111     0.815881     1.010954    -0.055435     0.811484
#
#    PINKY_DIP_Y  PINKY_DIP_Z  PINKY_TIP_X  PINKY_TIP_Y  PINKY_TIP_Z
# 0     1.055026    -0.046362     0.810923     1.079428    -0.048673
# 1     1.046382    -0.056060     0.796632     1.076262    -0.060052
# 2     1.041260    -0.058541     0.793435     1.073090    -0.063101
# 3     1.041650    -0.060612     0.793955     1.071162    -0.064699
# 4     1.046293    -0.063023     0.805646     1.078444    -0.068271
#
# [5 rows x 60 columns]

# %%
y = df.iloc[:,60:61]
y.head()
# Out:
#    CLASS
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x,y, train_size= 0.8)
print(X_test.shape)
print(X_train.shape)
# Out:
# (1101, 60)
# (4400, 60)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train,y)
# Out:
# StandardScaler()

# %%
print(X_train)
# Out:
#       THUMB_CMC_X  THUMB_CMC_Y  THUMB_CMC_Z  THUMB_MCP_X  THUMB_MCP_Y  \
# 2049     0.702894     0.939480     0.003666     0.709353     0.973369
# 1093     0.877041     0.712659    -0.029713     0.922000     0.644385
# 606      0.107207     0.632716    -0.012574     0.115399     0.596488
# 2464     0.491659     0.753360    -0.012827     0.519687     0.673196
# 3728     0.352100     0.421015    -0.026344     0.387619     0.399411
# ...           ...          ...          ...          ...          ...
# 2515     0.591641     0.616666     0.008761     0.579319     0.557375
# 2068     0.464502     0.223141    -0.006969     0.482988     0.173256
# 4746     0.218963     0.563509    -0.016935     0.213796     0.496773
# 3320     0.281798     0.658800    -0.005445     0.300871     0.617107
# 770      0.536655     0.492821    -0.011096     0.550764     0.468125
#
#       THUMB_MCP_Z  THUMB_IP_X  THUMB_IP_Y  THUMB_IP_Z  THUMB_TIP_X  ...  \
# 2049     0.004433    0.705754    0.999912    0.003825     0.699067  ...
# 1093    -0.045244    0.964449    0.588424   -0.061036     1.003798  ...
# 606     -0.019723    0.122852    0.564799   -0.026477     0.130177  ...
# 2464    -0.012598    0.517252    0.604039   -0.012459     0.486284  ...
# 3728    -0.059943    0.411884    0.359274   -0.090138     0.411585  ...
# ...           ...         ...         ...         ...          ...  ...
# 2515     0.006546    0.601743    0.517649    0.002625     0.635459  ...
# 2068    -0.006409    0.476892    0.130765   -0.005993     0.455563  ...
# 4746    -0.020911    0.177843    0.456119   -0.025068     0.144071  ...
# 3320    -0.009899    0.310804    0.582141   -0.014485     0.313498  ...
# 770     -0.018591    0.560511    0.448938   -0.025784     0.571432  ...
#
#       PINKY_MCP_Z  PINKY_PIP_X  PINKY_PIP_Y  PINKY_PIP_Z  PINKY_DIP_X  \
# 2049    -0.005429     0.679477     1.020710    -0.003638     0.678923
# 1093    -0.032890     0.696499     0.573530    -0.049849     0.663811
# 606     -0.017194     0.022339     0.618568    -0.025717     0.005860
# 2464    -0.003504     0.420526     0.628338    -0.020406     0.430904
# 3728    -0.070085     0.447550     0.667238    -0.075292     0.446308
# ...           ...          ...          ...          ...          ...
# 2515    -0.027096     0.677391     0.511418    -0.016147     0.674687
# 2068    -0.004514     0.415713     0.142815    -0.014355     0.423184
# 4746    -0.013484     0.144666     0.497241    -0.033845     0.160290
# 3320    -0.028372     0.314954     0.702867    -0.032327     0.306167
# 770     -0.025786     0.461878     0.429537    -0.035379     0.447778
#
#       PINKY_DIP_Y  PINKY_DIP_Z  PINKY_TIP_X  PINKY_TIP_Y  PINKY_TIP_Z
# 2049     1.034802     0.000117     0.678240     1.046454     0.002941
# 1093     0.553792    -0.056666     0.636238     0.535490    -0.058975
# 606      0.618289    -0.030303    -0.008054     0.616458    -0.032767
# 2464     0.665784    -0.013823     0.420008     0.677896    -0.004702
# 3728     0.650189    -0.068061     0.425981     0.639297    -0.062478
# ...           ...          ...          ...          ...          ...
# 2515     0.529797    -0.004785     0.673721     0.545563     0.002657
# 2068     0.167335    -0.009452     0.419077     0.179156    -0.003235
# 4746     0.520441    -0.033540     0.166812     0.540568    -0.028492
# 3320     0.702886    -0.030323     0.295527     0.698839    -0.029873
# 770      0.420796    -0.040622     0.436269     0.412999    -0.043829
#
# [4400 rows x 60 columns]

# %%
from sklearn.neural_network import MLPClassifier

mlp_model = MLPClassifier(hidden_layer_sizes = (60,40), max_iter= 1000)
mlp_model.fit(X_train,y_train.values.ravel())
# Out:
# MLPClassifier(hidden_layer_sizes=(60, 40), max_iter=1000)

# %%
predicted_y = mlp_model.predict(x)
print(predicted_y)
# Out:
# [0 0 0 ... 3 3 3]

# %%
from sklearn.metrics import classification_report
print(classification_report(y,predicted_y))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1559
#            1       1.00      1.00      1.00      1059
#            2       1.00      1.00      1.00      1428
#            3       1.00      1.00      1.00      1455
#
#     accuracy                           1.00      5501
#    macro avg       1.00      1.00      1.00      5501
# weighted avg       1.00      1.00      1.00      5501

# %%
import joblib

# Save the model
joblib.dump(mlp_model, 'mlp_classifier.joblib')
# Out:
# ['mlp_classifier.joblib']
